# %% [markdown]
# #### In this notebook we are testing several fine tuned Distilbert models trained by us on different datasets from PAN: 'gemini-pro', 'gpt-4-turbo-preview', 'gpt-3.5-turbo-0125', 'mistralai-mixtral-8x7b-instruct-v0.1', 'bigscience-bloomz-7b1', 'meta-llama-llama-2-7b-chat-hf', 'chavinlo-alpaca-13b'.
# #### All these are tested against texts from M4 coming from different generators from different domains: arxiv, reddit, wikihow and wikipedia. For each test the human texts per domain are combined with the texts from each LLM dataset.

# %%
import pandas as pd
import numpy as np
import torch
import json
import os
import torch.nn.functional as F

from tqdm import tqdm
from torch import nn
from transformers import DistilBertTokenizer, DistilBertForSequenceClassification
from torch.utils.data import Dataset, DataLoader, TensorDataset, SequentialSampler
from timeit import default_timer as timer
from os import walk
from pathlib import Path
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score, recall_score, precision_score, roc_curve, auc, brier_score_loss

# %%
ROOT_DATA = './'
M4_DATA_FOLDER_PATH = f'{ROOT_DATA}/raw/m4-unified'
FINE_TUNED_MODELS_FOLDER_PATH = f'{ROOT_DATA}/fine_tuned_models'

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !ls gdrive/MyDrive/tupotiite_na_daniel
# Out:
# fine_tuned_distilberts.zip  m4-unified.zip

# %%
# !unzip gdrive/MyDrive/tupotiite_na_daniel/fine_tuned_distilberts.zip
# Out:
# Archive:  gdrive/MyDrive/tupotiite_na_daniel/fine_tuned_distilberts.zip
#    creating: fine_tuned_models/
#    creating: fine_tuned_models/fine_tune_bert_gpt-4-turbo-preview.pt/
#   inflating: fine_tuned_models/fine_tune_bert_gpt-4-turbo-preview.pt/config.json
#   inflating: fine_tuned_models/fine_tune_bert_gpt-4-turbo-preview.pt/model.safetensors
#    creating: fine_tuned_models/fine_tune_bert_chavinlo-alpaca-13b.pt/
#   inflating: fine_tuned_models/fine_tune_bert_chavinlo-alpaca-13b.pt/config.json
#   inflating: fine_tuned_models/fine_tune_bert_chavinlo-alpaca-13b.pt/model.safetensors
#    creating: fine_tuned_models/fine_tune_bert_mistralai-mixtral-8x7b-instruct-v0.1.pt/
#   inflating: fine_tuned_models/fine_tune_bert_mistralai-mixtral-8x7b-instruct-v0.1.pt/config.json
#   inflating: fine_tuned_models/fine_tune_bert_mistralai-mixtral-8x7b-instruct-v0.1.pt/model.safetensors
#    creating: fine_tuned_models/fine_tune_bert_gemini-pro.pt/
#   inflating: fine_tuned_models/fine_tune_bert_gemini-pro.pt/config.json
#   inflating: fine_tuned_models/fine_tune_bert_gemini-pro.pt/model.safetensors
#    creating: fine_tuned_models/fine_tune_bert_gpt-3.5-turbo-0125.pt/
#   inflating: fine_tuned_models/fine_tune_bert_gpt-3.5-turbo-0125.pt/config.json
#   inflating: fine_tuned_models/fine_tune_bert_gpt-3.5-turbo-0125.pt/model.safetensors
#    creating: fine_tuned_models/fine_tune_bert_meta-llama-llama-2-7b-chat-hf.pt/
#   inflating: fine_tuned_models/fine_tune_bert_meta-llama-llama-2-7b-chat-hf.pt/config.json
#   inflating: fine_tuned_models/fine_tune_bert_meta-llama-llama-2-7b-chat-hf.pt/model.safetensors
#    creating: fine_tuned_models/fine_tune_bert_bigscience-bloomz-7b1.pt/
#   inflating: fine_tuned_models/fine_tune_bert_bigscience-bloomz-7b1.pt/config.json
#   inflating: fine_tuned_models/fine_tune_bert_bigscience-bloomz-7b1.pt/model.safetensors

# %%
# !unzip gdrive/MyDrive/tupotiite_na_daniel/m4-unified.zip
# Out:
# Archive:  gdrive/MyDrive/tupotiite_na_daniel/m4-unified.zip
#    creating: m4-unified/arxiv/
#   inflating: m4-unified/arxiv/arxiv_bloomz.jsonl
#   inflating: m4-unified/arxiv/arxiv_chatGPT.jsonl
#   inflating: m4-unified/arxiv/arxiv_cohere.jsonl
#   inflating: m4-unified/arxiv/arxiv_davinci.jsonl
#   inflating: m4-unified/arxiv/arxiv_flant5.jsonl
#   inflating: m4-unified/arxiv/arxiv_human.jsonl
#    creating: m4-unified/reddit/
#   inflating: m4-unified/reddit/reddit_bloomz.jsonl
#   inflating: m4-unified/reddit/reddit_chatGPT.jsonl
#   inflating: m4-unified/reddit/reddit_cohere.jsonl
#   inflating: m4-unified/reddit/reddit_davinci.jsonl
#   inflating: m4-unified/reddit/reddit_dolly.jsonl
#   inflating: m4-unified/reddit/reddit_flant5.jsonl
#   inflating: m4-unified/reddit/reddit_human.jsonl
#    creating: m4-unified/wikihow/
#   inflating: m4-unified/wikihow/wikihow_bloomz.jsonl
#   inflating: m4-unified/wikihow/wikihow_chatGPT.jsonl
#   inflating: m4-unified/wikihow/wikihow_cohere.jsonl
#   inflating: m4-unified/wikihow/wikihow_davinci.jsonl
#   inflating: m4-unified/wikihow/wikihow_dolly2.jsonl
#   inflating: m4-unified/wikihow/wikihow_human.jsonl
#    creating: m4-unified/wikipedia/
#   inflating: m4-unified/wikipedia/wikipedia_bloomz.jsonl
#   inflating: m4-unified/wikipedia/wikipedia_chatgpt.jsonl
#   inflating: m4-unified/wikipedia/wikipedia_cohere.jsonl
#   inflating: m4-unified/wikipedia/wikipedia_davinci.jsonl
#   inflating: m4-unified/wikipedia/wikipedia_dolly.jsonl
#   inflating: m4-unified/wikipedia/wikipedia_human.jsonl

# %%
TEST_SET_FRACTION = 0.3
BATCH_SIZE = 32

# %%
df = pd.DataFrame(columns=['text', 'is_llm', 'domain', 'dataset_name'])

# %%
dir_path, dir_names, file_names = next(walk(M4_DATA_FOLDER_PATH))

for dir in dir_names:
    dataset_folder_path, _, dataset_names = next(walk(os.path.join(dir_path, dir)))

    for dataset_name in dataset_names:
        temp_df = pd.read_json(path_or_buf=f'{dataset_folder_path}/{dataset_name}', lines=True)
        temp_df['domain'] = dir
        temp_df['dataset_name'] = Path(dataset_name).stem

        is_llm_column = 0 if 'human' in dataset_name else 1
        temp_df['is_llm'] = is_llm_column

        df = pd.concat([df, temp_df], ignore_index=True)

# %%
display(df)
# Out:
#                                                     text is_llm   domain  \
# 0      The present work is devoted to the study of qu...      1    arxiv
# 1      We present the results of our analysis of the ...      1    arxiv
# 2      We report on spectroscopic observations made w...      1    arxiv
# 3      We present new numerical methods for stochasti...      1    arxiv
# 4      The Solar Chromosphere is an important compone...      1    arxiv
# ...                                                  ...    ...      ...
# 74023  This is how you clean it when it's stuck.  You...      1  wikihow
# 74024  The following instructions describe how to bui...      1  wikihow
# 74025  The following steps show how to find out exact...      1  wikihow
# 74026  Coffee enemas have been used since ancient tim...      1  wikihow
# 74027  Coiling is an efficient way for climbers to st...      1  wikihow
#
#          dataset_name
# 0        arxiv_bloomz
# 1        arxiv_bloomz
# 2        arxiv_bloomz
# 3        arxiv_bloomz
# 4        arxiv_bloomz
# ...               ...
# 74023  wikihow_bloomz
# 74024  wikihow_bloomz
# 74025  wikihow_bloomz
# 74026  wikihow_bloomz
# 74027  wikihow_bloomz
#
# [74028 rows x 4 columns]

# %%
df = df.astype({'is_llm': 'int64'})

# %%
display(df)
# Out:
#                                                     text  is_llm   domain  \
# 0      The present work is devoted to the study of qu...       1    arxiv
# 1      We present the results of our analysis of the ...       1    arxiv
# 2      We report on spectroscopic observations made w...       1    arxiv
# 3      We present new numerical methods for stochasti...       1    arxiv
# 4      The Solar Chromosphere is an important compone...       1    arxiv
# ...                                                  ...     ...      ...
# 74023  This is how you clean it when it's stuck.  You...       1  wikihow
# 74024  The following instructions describe how to bui...       1  wikihow
# 74025  The following steps show how to find out exact...       1  wikihow
# 74026  Coffee enemas have been used since ancient tim...       1  wikihow
# 74027  Coiling is an efficient way for climbers to st...       1  wikihow
#
#          dataset_name
# 0        arxiv_bloomz
# 1        arxiv_bloomz
# 2        arxiv_bloomz
# 3        arxiv_bloomz
# 4        arxiv_bloomz
# ...               ...
# 74023  wikihow_bloomz
# 74024  wikihow_bloomz
# 74025  wikihow_bloomz
# 74026  wikihow_bloomz
# 74027  wikihow_bloomz
#
# [74028 rows x 4 columns]

# %%
tokenizer = DistilBertTokenizer.from_pretrained('distilbert-base-cased')
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/436k [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/465 [00:00<?, ?B/s]

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %%
def tokenize_texts(df, tokenizer):
    input_ids = []
    attention_masks = []
    for text in df.text.values:
        # `encode_plus` will:
        #   (1) Tokenize the sentence.
        #   (2) Prepend the `[CLS]` token to the start.
        #   (3) Append the `[SEP]` token to the end.
        #   (4) Map tokens to their IDs.
        #   (5) Pad or truncate the sentence to `max_length`
        #   (6) Create attention masks for [PAD] tokens.
        encoded_dict = tokenizer.encode_plus(
                            text,                      # Sentence to encode.
                            add_special_tokens = True, # Add '[CLS]' and '[SEP]'
                            max_length = 512,           # Pad & truncate all sentences.
                            padding='max_length',
                            truncation=True,
                            return_attention_mask = True,   # Construct attn. masks.
                            return_tensors = 'pt',     # Return pytorch tensors.
                       )

        # Add the encoded sentence to the list.
        input_ids.append(encoded_dict['input_ids'])

        # And its attention mask (simply differentiates padding from non-padding).
        attention_masks.append(encoded_dict['attention_mask'])

    input_ids = torch.cat(input_ids, dim=0)
    attention_masks = torch.cat(attention_masks, dim=0)
    labels = torch.from_numpy(df['is_llm'].values)

    return input_ids, attention_masks, labels

# %%
def calculate_accuracy(y_true, y_hat):
    correct_pred = torch.eq(y_hat, y_true).sum().item()
    return (correct_pred / len(y_hat)) * 100

def calculate_f1(y_true, y_hat):
    return f1_score(y_true, y_hat)

def calculate_recall(y_true, y_hat):
    return recall_score(y_true, y_hat)

def calculate_precision(y_true, y_hat):
    return precision_score(y_true, y_hat)

def calculate_brier(y_true, y_hat):
    y_prob = torch.sigmoid(y_hat)
    return brier_score_loss(y_true, y_prob)

def calculate_auc(y_true, y_hat):
    y_prob = torch.sigmoid(y_hat)

    false_positive_rates, true_positive_rates, _ = roc_curve(y_true, y_prob)
    roc_auc = auc(false_positive_rates, true_positive_rates)

    return roc_auc, false_positive_rates, true_positive_rates

# %%
def test_step(model, dataloader, device):

    model.eval()

    all_y_true = []
    all_y_hat = []

    test_loss = 0
    steps = 0

    with torch.inference_mode():
        for batch in dataloader:
            batch_input_ids = batch[0].to(device)
            batch_input_mask = batch[1].to(device)
            batch_labels = batch[2].to(device)

            y_hat = model(batch_input_ids,
                          attention_mask=batch_input_mask,
                          labels=batch_labels)

            loss = y_hat.loss
            test_loss += loss.item()

            logits = y_hat.logits

            batch_labels = batch_labels.to('cpu').numpy()

            all_y_true.extend(batch_labels)
            all_y_hat.extend(logits.detach().cpu().numpy())

            steps += 1

        all_y_true = torch.FloatTensor(all_y_true)
        all_y_hat = torch.argmax(torch.FloatTensor(all_y_hat), dim=1)

        test_accuracy = calculate_accuracy(all_y_true, all_y_hat)
        test_f1 = calculate_f1(all_y_true, all_y_hat)
        test_recall = calculate_recall(all_y_true, all_y_hat)
        test_precision = calculate_precision(all_y_true, all_y_hat)
        # cannot calculate brier and auc because of the output of the distilbert model

    return test_loss / steps, test_accuracy, test_f1, test_recall, test_precision, 0, 0

def test_against_all(model, df, device, tokenizer):
    all_results = []

    for dataset_name in df['dataset_name'].unique():
        if 'human' in dataset_name:
            continue

        llm_df = df.loc[(df['dataset_name'] == dataset_name) & (df['is_llm'] == 1)]

        domain = llm_df['domain'].iloc[0]
        human_df = df.loc[(df['domain'] == domain) & (df['is_llm'] == 0)]

        test_df = pd.concat([llm_df, human_df], ignore_index=True)

        results_formatted = test(model, device, dataset_name, test_df, tokenizer)

        all_results.append({
            dataset_name: results_formatted
        })

    return all_results

def test(model, device, dataset_name, test_df, tokenizer):
    input_ids, attention_masks, labels = tokenize_texts(test_df, tokenizer)
    dataset = TensorDataset(input_ids, attention_masks, labels)

    # For validation the order doesn't matter, so we'll just read them sequentially.
    validation_dataloader = DataLoader(
            dataset, # The validation samples.
            sampler = SequentialSampler(dataset), # Pull out batches sequentially.
            batch_size = BATCH_SIZE # Evaluate with this batch size.
        )

    start_time = timer()

    test_loss, test_acc, test_f1, test_recall, test_precision, test_brier, test_auc_tuple = test_step(
        model,
        validation_dataloader,
        device
    )

    end_time = timer()

    results_formatted = {
            "test_loss": test_loss,
            "test_acc": test_acc,
            "test_f1": test_f1,
            "test_recall": test_recall,
            "test_precision": test_precision,
            "test_brier": test_brier,
            "test_auc_tuple": test_auc_tuple
        }

    print(
            f"against: {dataset_name} | "
            f"test_loss: {test_loss:.4f} | "
            f"test_acc: {test_acc:.4f} | "
            f"test_f1: {test_f1:.4f} | "
            f"test_recall: {test_recall:.4f} | "
            f"test_precision: {test_precision:.4f} | "
            f"test_brier: {test_brier:.4f} | "
            f"time: {(end_time-start_time):.4f}"
        )

    return results_formatted

# %%
human_df = df.loc[df['is_llm'] == 0]
human_train_df, human_test_df = train_test_split(human_df, test_size=TEST_SET_FRACTION, random_state=69)

# %%
# models_to_test = [
#     'fine_tune_bert_bigscience-bloomz-7b1',
#     'fine_tune_bert_gemini-pro',
#     'fine_tune_bert_gpt-3.5-turbo-0125',
#     'fine_tune_bert_gpt-4-turbo-preview',
#     'fine_tune_bert_mistralai-mixtral-8x7b-instruct-v0.1'
# ]

models_to_test = [
    'fine_tune_bert_bigscience-bloomz-7b1',
    'fine_tune_bert_gemini-pro'
]

# %%
final_results = []

for model_name in models_to_test:
    model_path = f'{FINE_TUNED_MODELS_FOLDER_PATH}/{model_name}'

    model = DistilBertForSequenceClassification.from_pretrained(
        model_path,
        num_labels = 2,
        output_attentions = False, # Whether the model returns attentions weights.
        output_hidden_states = False, # Whether the model returns all hidden-states.
    )

    model.to(device)

    print(f'Testing against M4 data for fined tuned distilbert on {model_name}...')

    results = test_against_all(
        model=model,
        df=df,
        device=device,
        tokenizer=tokenizer
    )

    final_results.append({
        'base_model': model_name,
        'results_against_all_llms': results
    })

    print(f'Finished testing against M4 data for fined tuned distilbert on {model_name}')
# Out:
# Testing against M4 data for fined tuned distilbert on fine_tune_bert_bigscience-bloomz-7b1...
# against: arxiv_bloomz | test_loss: 2.6081 | test_acc: 51.5833 | test_f1: 0.4850 | test_recall: 0.4560 | test_precision: 0.5180 | test_brier: 0.0000 | time: 103.1603
# against: arxiv_cohere | test_loss: 1.4244 | test_acc: 71.5000 | test_f1: 0.7499 | test_recall: 0.8543 | test_precision: 0.6681 | test_brier: 0.0000 | time: 102.6315
# against: arxiv_davinci | test_loss: 1.6556 | test_acc: 65.9667 | test_f1: 0.6860 | test_recall: 0.7437 | test_precision: 0.6367 | test_brier: 0.0000 | time: 102.4701
# against: arxiv_flant5 | test_loss: 1.1231 | test_acc: 77.0500 | test_f1: 0.8079 | test_recall: 0.9653 | test_precision: 0.6947 | test_brier: 0.0000 | time: 102.1080
# against: arxiv_chatGPT | test_loss: 1.1961 | test_acc: 75.4833 | test_f1: 0.7921 | test_recall: 0.9340 | test_precision: 0.6876 | test_brier: 0.0000 | time: 102.7293
# against: reddit_bloomz | test_loss: 1.0516 | test_acc: 79.9000 | test_f1: 0.8042 | test_recall: 0.8253 | test_precision: 0.7840 | test_brier: 0.0000 | time: 102.6753
# against: reddit_chatGPT | test_loss: 0.7990 | test_acc: 84.4167 | test_f1: 0.8546 | test_recall: 0.9157 | test_precision: 0.8011 | test_brier: 0.0000 | time: 103.0177
# against: reddit_dolly | test_loss: 1.1349 | test_acc: 79.5167 | test_f1: 0.7997 | test_recall: 0.8177 | test_precision: 0.7825 | test_brier: 0.0000 | time: 103.0846
# against: reddit_davinci | test_loss: 1.5693 | test_acc: 71.7500 | test_f1: 0.7010 | test_recall: 0.6623 | test_precision: 0.7445 | test_brier: 0.0000 | time: 103.2964
# against: reddit_flant5 | test_loss: 0.6208 | test_acc: 88.3500 | test_f1: 0.8951 | test_recall: 0.9943 | test_precision: 0.8139 | test_brier: 0.0000 | time: 102.3437
# against: reddit_cohere | test_loss: 0.9663 | test_acc: 58.2333 | test_f1: 0.4841 | test_recall: 0.3920 | test_precision: 0.6329 | test_brier: 0.0000 | time: 101.8008
# against: wikipedia_cohere | test_loss: 0.8653 | test_acc: 82.1609 | test_f1: 0.8085 | test_recall: 0.8592 | test_precision: 0.7634 | test_brier: 0.0000 | time: 91.9036
# against: wikipedia_bloomz | test_loss: 0.7688 | test_acc: 84.6205 | test_f1: 0.8542 | test_recall: 0.9000 | test_precision: 0.8128 | test_brier: 0.0000 | time: 102.6133
# against: wikipedia_davinci | test_loss: 1.6075 | test_acc: 69.4746 | test_f1: 0.6620 | test_recall: 0.5973 | test_precision: 0.7423 | test_brier: 0.0000 | time: 103.6128
# against: wikipedia_chatgpt | test_loss: 0.7130 | test_acc: 84.8915 | test_f1: 0.8570 | test_recall: 0.9055 | test_precision: 0.8134 | test_brier: 0.0000 | time: 103.2084
# against: wikipedia_dolly | test_loss: 1.3941 | test_acc: 73.6352 | test_f1: 0.7081 | test_recall: 0.6743 | test_precision: 0.7455 | test_brier: 0.0000 | time: 98.3448
# against: wikihow_davinci | test_loss: 3.1165 | test_acc: 48.5167 | test_f1: 0.3195 | test_recall: 0.2417 | test_precision: 0.4711 | test_brier: 0.0000 | time: 103.7495
# against: wikihow_dolly2 | test_loss: 2.6897 | test_acc: 54.6167 | test_f1: 0.4449 | test_recall: 0.3637 | test_precision: 0.5727 | test_brier: 0.0000 | time: 103.6513
# against: wikihow_cohere | test_loss: 1.3272 | test_acc: 74.0833 | test_f1: 0.7439 | test_recall: 0.7530 | test_precision: 0.7351 | test_brier: 0.0000 | time: 103.2903
# against: wikihow_chatGPT | test_loss: 2.3583 | test_acc: 57.8667 | test_f1: 0.5043 | test_recall: 0.4287 | test_precision: 0.6124 | test_brier: 0.0000 | time: 103.8897
# against: wikihow_bloomz | test_loss: 2.7638 | test_acc: 51.7167 | test_f1: 0.3877 | test_recall: 0.3057 | test_precision: 0.5298 | test_brier: 0.0000 | time: 103.4275
# Finished testing against M4 data for fined tuned distilbert on fine_tune_bert_bigscience-bloomz-7b1
# Testing against M4 data for fined tuned distilbert on fine_tune_bert_gemini-pro...
# against: arxiv_bloomz | test_loss: 2.3922 | test_acc: 48.7667 | test_f1: 0.2162 | test_recall: 0.1413 | test_precision: 0.4599 | test_brier: 0.0000 | time: 102.8594
# against: arxiv_cohere | test_loss: 1.4947 | test_acc: 61.8500 | test_f1: 0.5137 | test_recall: 0.4030 | test_precision: 0.7083 | test_brier: 0.0000 | time: 102.8267
# against: arxiv_davinci | test_loss: 1.2007 | test_acc: 66.9167 | test_f1: 0.6039 | test_recall: 0.5043 | test_precision: 0.7524 | test_brier: 0.0000 | time: 102.6245
# against: arxiv_flant5 | test_loss: 0.4447 | test_acc: 86.3667 | test_f1: 0.8676 | test_recall: 0.8933 | test_precision: 0.8433 | test_brier: 0.0000 | time: 102.3054
# against: arxiv_chatGPT | test_loss: 0.3108 | test_acc: 89.5833 | test_f1: 0.9019 | test_recall: 0.9577 | test_precision: 0.8523 | test_brier: 0.0000 | time: 102.8224
# against: reddit_bloomz | test_loss: 3.9231 | test_acc: 50.4500 | test_f1: 0.0224 | test_recall: 0.0113 | test_precision: 0.8293 | test_brier: 0.0000 | time: 102.8066
# against: reddit_chatGPT | test_loss: 2.1278 | test_acc: 68.9167 | test_f1: 0.5505 | test_recall: 0.3807 | test_precision: 0.9939 | test_brier: 0.0000 | time: 102.9104
# against: reddit_dolly | test_loss: 2.8703 | test_acc: 58.0000 | test_f1: 0.2788 | test_recall: 0.1623 | test_precision: 0.9858 | test_brier: 0.0000 | time: 103.2423
# against: reddit_davinci | test_loss: 2.8644 | test_acc: 59.3500 | test_f1: 0.3178 | test_recall: 0.1893 | test_precision: 0.9878 | test_brier: 0.0000 | time: 103.5455
# against: reddit_flant5 | test_loss: 0.7830 | test_acc: 81.0333 | test_f1: 0.7666 | test_recall: 0.6230 | test_precision: 0.9963 | test_brier: 0.0000 | time: 102.5953
# against: reddit_cohere | test_loss: 0.8892 | test_acc: 86.6167 | test_f1: 0.8459 | test_recall: 0.7347 | test_precision: 0.9968 | test_brier: 0.0000 | time: 101.9912
# against: wikipedia_cohere | test_loss: 0.9977 | test_acc: 75.1266 | test_f1: 0.6919 | test_recall: 0.6374 | test_precision: 0.7566 | test_brier: 0.0000 | time: 91.9977
# against: wikipedia_bloomz | test_loss: 1.4687 | test_acc: 56.2302 | test_f1: 0.3946 | test_recall: 0.2850 | test_precision: 0.6409 | test_brier: 0.0000 | time: 102.6430
# against: wikipedia_davinci | test_loss: 0.8476 | test_acc: 78.8324 | test_f1: 0.7769 | test_recall: 0.7367 | test_precision: 0.8219 | test_brier: 0.0000 | time: 103.7196
# against: wikipedia_chatgpt | test_loss: 0.3471 | test_acc: 90.2504 | test_f1: 0.9082 | test_recall: 0.9649 | test_precision: 0.8578 | test_brier: 0.0000 | time: 103.4326
# against: wikipedia_dolly | test_loss: 1.9004 | test_acc: 62.2082 | test_f1: 0.4885 | test_recall: 0.3805 | test_precision: 0.6821 | test_brier: 0.0000 | time: 98.4178
# against: wikihow_davinci | test_loss: 4.0712 | test_acc: 51.1000 | test_f1: 0.0480 | test_recall: 0.0247 | test_precision: 0.9024 | test_brier: 0.0000 | time: 103.9113
# against: wikihow_dolly2 | test_loss: 3.9527 | test_acc: 50.8333 | test_f1: 0.0378 | test_recall: 0.0193 | test_precision: 0.8788 | test_brier: 0.0000 | time: 103.6202
# against: wikihow_cohere | test_loss: 3.5367 | test_acc: 53.8500 | test_f1: 0.1472 | test_recall: 0.0797 | test_precision: 0.9676 | test_brier: 0.0000 | time: 103.6058
# against: wikihow_chatGPT | test_loss: 3.9023 | test_acc: 51.5000 | test_f1: 0.0631 | test_recall: 0.0327 | test_precision: 0.9245 | test_brier: 0.0000 | time: 103.9305
# against: wikihow_bloomz | test_loss: 4.1426 | test_acc: 50.0667 | test_f1: 0.0079 | test_recall: 0.0040 | test_precision: 0.6000 | test_brier: 0.0000 | time: 103.2738
# Finished testing against M4 data for fined tuned distilbert on fine_tune_bert_gemini-pro

# %%
# Create a JSON Encoder class
class json_serialize(json.JSONEncoder):
    def default(self, obj):
        if isinstance(obj, np.integer):
            return int(obj)
        if isinstance(obj, np.floating):
            return float(obj)
        if isinstance(obj, np.ndarray):
            return obj.tolist()
        return json.JSONEncoder.default(self, obj)

with open('./vs_m4.json', 'w', encoding='utf-8') as f:
    json.dump(final_results, f, ensure_ascii=False, indent=4, cls=json_serialize)

# %%
# !cp ./vs_m4_v2.json '/content/gdrive/My Drive/'
