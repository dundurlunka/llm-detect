# %% [markdown]
# #### In this notebook we are testing several LSTM models trained by us on different datasets from PAN: 'gemini-pro', 'gpt-4-turbo-preview', 'gpt-3.5-turbo-0125' 'mistralai-mixtral-8x7b-instruct-v0.1', 'all_vs_all_epoch_16'.
# #### All these are tested against texts from M4 coming from different generators from different domains: arxiv, reddit, wikihow and wikipedia. For each test the human texts per domain are combined with the texts from each LLM dataset.

# %%
import pandas as pd
import numpy as np
import torch
import json
import os

from tqdm import tqdm
from torch import nn
from transformers import AutoTokenizer
from torch.utils.data import Dataset, DataLoader
from timeit import default_timer as timer
from os import walk
from pathlib import Path
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score, recall_score, precision_score, roc_curve, auc, brier_score_loss

# %%
ROOT_DATA = './'
M4_DATA_FOLDER_PATH = f'{ROOT_DATA}/raw/m4-unified'
BASELINE_MODELS_FOLDER_PATH = f'{ROOT_DATA}/baseline/models'

# %%
BATCH_SIZE = 32
LSTM_UNITS = 256
LSTM_LAYERS = 5
EMBEDDING_SIZE = 512

# %%
TEST_SET_FRACTION = 0.3

# %%
df = pd.DataFrame(columns=['text', 'is_llm', 'domain', 'dataset_name'])

# %%
dir_path, dir_names, file_names = next(walk(M4_DATA_FOLDER_PATH))

for dir in dir_names:
    dataset_folder_path, _, dataset_names = next(walk(os.path.join(dir_path, dir)))

    for dataset_name in dataset_names:
        temp_df = pd.read_json(path_or_buf=f'{dataset_folder_path}/{dataset_name}', lines=True)
        temp_df['domain'] = dir
        temp_df['dataset_name'] = Path(dataset_name).stem

        is_llm_dataset = 0 if 'human' in dataset_name else 1
        temp_df['is_llm'] = is_llm_dataset

        df = pd.concat([df, temp_df], ignore_index=True)

# %%
display(df)
# Out:
#                                                     text is_llm  domain  \
# 0      In this paper, we investigate the continuum li...      1   arxiv
# 1      In this paper, we present the results of our a...      1   arxiv
# 2      In this work, we present the results of high-r...      1   arxiv
# 3      In this work, we present a new method of integ...      1   arxiv
# 4      In this study, we present the use of Atacama L...      1   arxiv
# ...                                                  ...    ...     ...
# 74023  Well, to be honest, it's kind of complicated h...      1  reddit
# 74024  The prevalence of draws in chess among the top...      1  reddit
# 74025  So, you know how when you're driving with your...      1  reddit
# 74026  Nightmares are disturbing and distressing drea...      1  reddit
# 74027  The negative perception of Gypsies or Roma peo...      1  reddit
#
#          dataset_name
# 0       arxiv_chatGPT
# 1       arxiv_chatGPT
# 2       arxiv_chatGPT
# 3       arxiv_chatGPT
# 4       arxiv_chatGPT
# ...               ...
# 74023  reddit_chatGPT
# 74024  reddit_chatGPT
# 74025  reddit_chatGPT
# 74026  reddit_chatGPT
# 74027  reddit_chatGPT
#
# [74028 rows x 4 columns]

# %%
checkpoint = 'distilbert-base-cased'
tokenizer = AutoTokenizer.from_pretrained(checkpoint)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/465 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/436k [00:00<?, ?B/s]

# %%
df['tokenized_text'] = tokenizer(list(df['text'].to_list()))['input_ids']
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (559 > 512). Running this sequence through the model will result in indexing errors

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %%
class RNN(nn.Module):
    def __init__(self, vocab_size, embedding_size, hidden_size, layers_num, device, output_size=1, dropout=0):
        super().__init__()

        self.vocab_size = vocab_size
        self.embedding_size = embedding_size
        self.hidden_size = hidden_size
        self.layers_num = layers_num
        self.output_size= output_size
        self.dropout = dropout
        self.device = device

        self.embed = nn.Embedding(self.vocab_size, self.embedding_size, device=self.device)

        self.lstm = nn.LSTM(
            input_size=self.embedding_size,
            hidden_size=self.hidden_size,
            num_layers=self.layers_num,
            batch_first=True,
            dropout=self.dropout,
            device=self.device
        )

        self.fc = nn.Linear(
            self.hidden_size,
            self.output_size
        )

    def forward(self, X, lengths):
        embeddings = self.embed(X)

        seq_output, (h_n, c_n) = self.lstm(embeddings)

        out = seq_output.sum(dim=1).div(lengths.float().unsqueeze(dim=1))
        logits = self.fc(out)
        return logits

# %%
class TextDataset(Dataset):
    def __init__(self, X, y):
        self.X = X
        self.y = y

    def __len__(self):
        return self.X.size

    def __getitem__(self, index):
        return (
            self.X[index],
            self.y[index]
        )

# %%
def collate_fn(batch):
  # We want to sort the batch by seq length,
  # in order to make the computation more efficient
  batch = sorted(batch, key=lambda x: len(x[0]), reverse=True)

  inputs = [torch.LongTensor(x[0]).to(device) for x in batch]
  padded_input = nn.utils.rnn.pad_sequence(inputs, batch_first=True)

  lengths = torch.LongTensor([len(x[0]) for x in batch]).to(device)

  y = torch.FloatTensor(np.array([x[1] for x in batch])).reshape(-1, 1).to(device)

  return padded_input, lengths, y

# %%
def calculate_accuracy(y_true, y_hat):
    correct_pred = torch.eq(torch.sigmoid(y_hat).round(), y_true).sum().item()
    return (correct_pred / len(y_hat)) * 100

def calculate_f1(y_true, y_hat):
    y_pred = torch.sigmoid(y_hat).round()
    return f1_score(y_true, y_pred)

def calculate_recall(y_true, y_hat):
    y_pred = torch.sigmoid(y_hat).round()
    return recall_score(y_true, y_pred)

def calculate_precision(y_true, y_hat):
    y_pred = torch.sigmoid(y_hat).round()
    return precision_score(y_true, y_pred)

def calculate_brier(y_true, y_hat):
    y_prob = torch.sigmoid(y_hat)
    return brier_score_loss(y_true, y_prob)

def calculate_auc(y_true, y_hat):
    y_prob = torch.sigmoid(y_hat)

    false_positive_rates, true_positive_rates, _ = roc_curve(y_true, y_prob)
    roc_auc = auc(false_positive_rates, true_positive_rates)

    return roc_auc, false_positive_rates, true_positive_rates

# %%
def test_step(model, dataloader, loss_fn, device):

    model.eval()

    all_y_true = []
    all_y_hat = []

    test_loss = 0
    steps = 0

    with torch.inference_mode():
        for X, lengths, y in dataloader:

            X, y = X.to(device), y.to(device)

            y_hat = model(X, lengths)

            all_y_true.extend(y)
            all_y_hat.extend(y_hat)

            loss = loss_fn(y_hat, y)
            test_loss += loss.item()

            steps += 1

        all_y_true = torch.FloatTensor(all_y_true)
        all_y_hat = torch.FloatTensor(all_y_hat)

        test_accuracy = calculate_accuracy(all_y_true, all_y_hat)
        test_f1 = calculate_f1(all_y_true, all_y_hat)
        test_recall = calculate_recall(all_y_true, all_y_hat)
        test_precision = calculate_precision(all_y_true, all_y_hat)
        test_brier = calculate_brier(all_y_true, all_y_hat)
        test_auc_tuple = calculate_auc(all_y_true, all_y_hat)

    return test_loss / steps, test_accuracy, test_f1, test_recall, test_precision, test_brier, test_auc_tuple

def test_against_all(model, df, loss_fn, device):
    all_results = []

    for dataset_name in df['dataset_name'].unique():
        if 'human' in dataset_name:
            continue

        llm_df = df.loc[(df['dataset_name'] == dataset_name) & (df['is_llm'] == 1)]

        domain = llm_df['domain'].iloc[0]
        human_df = df.loc[(df['domain'] == domain) & (df['is_llm'] == 0)]

        test_df = pd.concat([llm_df, human_df], ignore_index=True)

        results_formatted = test(model, loss_fn, device, dataset_name, test_df)

        all_results.append({
            dataset_name: results_formatted
        })

    return all_results

def test(model, loss_fn, device, dataset_name, test_df):
    test_dataset_full = TextDataset(test_df['tokenized_text'], test_df['is_llm'])
    test_dataloader_full = DataLoader(
            test_dataset_full,
            batch_size=BATCH_SIZE,
            shuffle=False,
            drop_last=False,
            collate_fn=collate_fn
        )

    start_time = timer()

    test_loss, test_acc, test_f1, test_recall, test_precision, test_brier, test_auc_tuple = test_step(
            model,
            test_dataloader_full,
            loss_fn,
            device
        )

    end_time = timer()

    results_formatted = {
            "test_loss": test_loss,
            "test_acc": test_acc,
            "test_f1": test_f1,
            "test_recall": test_recall,
            "test_precision": test_precision,
            "test_brier": test_brier,
            "test_auc_tuple": test_auc_tuple
        }

    print(
            f"against: {dataset_name} | "
            f"test_loss: {test_loss:.4f} | "
            f"test_acc: {test_acc:.4f} | "
            f"test_f1: {test_f1:.4f} | "
            f"test_recall: {test_recall:.4f} | "
            f"test_precision: {test_precision:.4f} | "
            f"test_brier: {test_brier:.4f} | "
            f"time: {(end_time-start_time):.4f}"
        )

    return results_formatted

# %%
human_df = df.loc[df['is_llm'] == 0]
human_train_df, human_test_df = train_test_split(human_df, test_size=TEST_SET_FRACTION, random_state=69)

# %%
models_to_test = [
    'gemini-pro',
    'gpt-4-turbo-preview',
    'gpt-3.5-turbo-0125',
    'mistralai-mixtral-8x7b-instruct-v0.1',
    '/all_vs_all/all_vs_all_epoch_16',
]

# %%
final_results = []

for model_name in models_to_test:
    model_path = f'{BASELINE_MODELS_FOLDER_PATH}/{model_name}.pt'

    model = RNN(tokenizer.vocab_size, EMBEDDING_SIZE, LSTM_UNITS, LSTM_LAYERS, device, dropout=0.6).to(device)
    model.load_state_dict(torch.load(model_path, map_location=device))

    loss_fn = nn.BCEWithLogitsLoss()

    print(f'Testing against M4 data for LSTM {model_name}...')

    results = test_against_all(
        model=model,
        df=df,
        loss_fn=loss_fn,
        device=device
    )

    final_results.append({
        'base_model': model_name,
        'results_against_all_llms': results
    })

    print(f'Finished testing against M4 data for LSTM {model_name}')
# Out:
# Testing against M4 data for LSTM gemini-pro...
# against: arxiv_chatGPT | test_loss: 1.2772 | test_acc: 59.2833 | test_f1: 0.3801 | test_recall: 0.2497 | test_precision: 0.7960 | test_brier: 0.3465 | time: 8.5515
# against: arxiv_bloomz | test_loss: 2.0658 | test_acc: 48.0667 | test_f1: 0.0465 | test_recall: 0.0253 | test_precision: 0.2836 | test_brier: 0.4755 | time: 8.1541
# against: arxiv_flant5 | test_loss: 2.0157 | test_acc: 65.5667 | test_f1: 0.5215 | test_recall: 0.3753 | test_precision: 0.8543 | test_brier: 0.3308 | time: 6.5020
# against: arxiv_davinci | test_loss: 2.0704 | test_acc: 50.2000 | test_f1: 0.1201 | test_recall: 0.0680 | test_precision: 0.5152 | test_brier: 0.4647 | time: 7.0294
# against: arxiv_cohere | test_loss: 1.7320 | test_acc: 54.7833 | test_f1: 0.2610 | test_recall: 0.1597 | test_precision: 0.7139 | test_brier: 0.4076 | time: 8.0169
# against: wikihow_cohere | test_loss: 2.6330 | test_acc: 51.9333 | test_f1: 0.0745 | test_recall: 0.0387 | test_precision: 1.0000 | test_brier: 0.4590 | time: 48.6934
# against: wikihow_chatGPT | test_loss: 2.2687 | test_acc: 50.3833 | test_f1: 0.0152 | test_recall: 0.0077 | test_precision: 1.0000 | test_brier: 0.4743 | time: 55.1447
# against: wikihow_dolly2 | test_loss: 2.6627 | test_acc: 50.7833 | test_f1: 0.0309 | test_recall: 0.0157 | test_precision: 1.0000 | test_brier: 0.4731 | time: 50.1307
# against: wikihow_bloomz | test_loss: 2.4994 | test_acc: 50.5000 | test_f1: 0.0198 | test_recall: 0.0100 | test_precision: 1.0000 | test_brier: 0.4790 | time: 47.2973
# against: wikihow_davinci | test_loss: 2.6393 | test_acc: 50.1833 | test_f1: 0.0073 | test_recall: 0.0037 | test_precision: 1.0000 | test_brier: 0.4817 | time: 55.8826
# against: wikipedia_cohere | test_loss: 1.4559 | test_acc: 65.8601 | test_f1: 0.3645 | test_recall: 0.2235 | test_precision: 0.9886 | test_brier: 0.3074 | time: 63.5338
# against: wikipedia_chatgpt | test_loss: 0.7559 | test_acc: 75.7429 | test_f1: 0.6806 | test_recall: 0.5169 | test_precision: 0.9961 | test_brier: 0.1999 | time: 62.6368
# against: wikipedia_davinci | test_loss: 1.0396 | test_acc: 66.7223 | test_f1: 0.5029 | test_recall: 0.3363 | test_precision: 0.9961 | test_brier: 0.2783 | time: 62.7801
# against: wikipedia_bloomz | test_loss: 4.1957 | test_acc: 51.1593 | test_f1: 0.0494 | test_recall: 0.0253 | test_precision: 0.9500 | test_brier: 0.4805 | time: 60.9716
# against: wikipedia_dolly | test_loss: 1.7614 | test_acc: 58.9609 | test_f1: 0.2404 | test_recall: 0.1369 | test_precision: 0.9840 | test_brier: 0.3729 | time: 66.9179
# against: reddit_bloomz | test_loss: 2.0885 | test_acc: 50.6667 | test_f1: 0.0282 | test_recall: 0.0143 | test_precision: 0.9348 | test_brier: 0.4712 | time: 18.2815
# against: reddit_davinci | test_loss: 1.5800 | test_acc: 54.2667 | test_f1: 0.1588 | test_recall: 0.0863 | test_precision: 0.9885 | test_brier: 0.4056 | time: 19.8032
# against: reddit_cohere | test_loss: 16.4814 | test_acc: 52.0333 | test_f1: 0.0799 | test_recall: 0.0417 | test_precision: 0.9766 | test_brier: 0.2957 | time: 17.7027
# against: reddit_flant5 | test_loss: 2.4495 | test_acc: 61.8000 | test_f1: 0.3829 | test_recall: 0.2370 | test_precision: 0.9958 | test_brier: 0.3756 | time: 17.4244
# against: reddit_dolly | test_loss: 1.8224 | test_acc: 55.1000 | test_f1: 0.1866 | test_recall: 0.1030 | test_precision: 0.9904 | test_brier: 0.4075 | time: 20.8475
# against: reddit_chatGPT | test_loss: 1.5172 | test_acc: 58.5667 | test_f1: 0.2937 | test_recall: 0.1723 | test_precision: 0.9942 | test_brier: 0.3663 | time: 19.6869
# Finished testing against M4 data for LSTM gemini-pro
# Testing against M4 data for LSTM gpt-4-turbo-preview...
# against: arxiv_chatGPT | test_loss: 0.8312 | test_acc: 68.5167 | test_f1: 0.6188 | test_recall: 0.5110 | test_precision: 0.7841 | test_brier: 0.2448 | time: 7.7758
# against: arxiv_bloomz | test_loss: 2.3588 | test_acc: 47.4000 | test_f1: 0.1429 | test_recall: 0.0877 | test_precision: 0.3856 | test_brier: 0.4673 | time: 9.0561
# against: arxiv_flant5 | test_loss: 4.8578 | test_acc: 46.5833 | test_f1: 0.1193 | test_recall: 0.0723 | test_precision: 0.3396 | test_brier: 0.5079 | time: 7.2108
# against: arxiv_davinci | test_loss: 1.4641 | test_acc: 58.8500 | test_f1: 0.4357 | test_recall: 0.3177 | test_precision: 0.6931 | test_brier: 0.3441 | time: 7.7543
# against: arxiv_cohere | test_loss: 2.1615 | test_acc: 48.8833 | test_f1: 0.1880 | test_recall: 0.1183 | test_precision: 0.4569 | test_brier: 0.4535 | time: 8.8408
# against: wikihow_cohere | test_loss: 4.5378 | test_acc: 50.5000 | test_f1: 0.0269 | test_recall: 0.0137 | test_precision: 0.7885 | test_brier: 0.4838 | time: 53.2716
# against: wikihow_chatGPT | test_loss: 3.1011 | test_acc: 50.0833 | test_f1: 0.0106 | test_recall: 0.0053 | test_precision: 0.5926 | test_brier: 0.4807 | time: 57.6962
# against: wikihow_dolly2 | test_loss: 3.7332 | test_acc: 51.9000 | test_f1: 0.0797 | test_recall: 0.0417 | test_precision: 0.9191 | test_brier: 0.4547 | time: 51.5272
# against: wikihow_bloomz | test_loss: 3.2735 | test_acc: 52.4167 | test_f1: 0.0985 | test_recall: 0.0520 | test_precision: 0.9341 | test_brier: 0.4581 | time: 47.8051
# against: wikihow_davinci | test_loss: 3.8485 | test_acc: 50.1833 | test_f1: 0.0145 | test_recall: 0.0073 | test_precision: 0.6667 | test_brier: 0.4801 | time: 55.9246
# against: wikipedia_cohere | test_loss: 2.4972 | test_acc: 58.5256 | test_f1: 0.1473 | test_recall: 0.0818 | test_precision: 0.7432 | test_brier: 0.3849 | time: 63.6314
# against: wikipedia_chatgpt | test_loss: 1.1087 | test_acc: 68.4641 | test_f1: 0.5523 | test_recall: 0.3890 | test_precision: 0.9518 | test_brier: 0.2587 | time: 62.6244
# against: wikipedia_davinci | test_loss: 1.1546 | test_acc: 63.7031 | test_f1: 0.4488 | test_recall: 0.2953 | test_precision: 0.9346 | test_brier: 0.2928 | time: 62.7488
# against: wikipedia_bloomz | test_loss: 8.3103 | test_acc: 51.7765 | test_f1: 0.1058 | test_recall: 0.0570 | test_precision: 0.7339 | test_brier: 0.4716 | time: 60.9418
# against: wikipedia_dolly | test_loss: 2.6378 | test_acc: 56.1348 | test_f1: 0.1728 | test_recall: 0.0966 | test_precision: 0.8182 | test_brier: 0.4012 | time: 66.9646
# against: reddit_bloomz | test_loss: 2.2490 | test_acc: 52.4000 | test_f1: 0.1047 | test_recall: 0.0557 | test_precision: 0.8789 | test_brier: 0.4481 | time: 18.1482
# against: reddit_davinci | test_loss: 1.2122 | test_acc: 64.3667 | test_f1: 0.4529 | test_recall: 0.2950 | test_precision: 0.9747 | test_brier: 0.3007 | time: 19.7217
# against: reddit_cohere | test_loss: 43.2356 | test_acc: 51.0167 | test_f1: 0.0541 | test_recall: 0.0280 | test_precision: 0.7850 | test_brier: 0.3049 | time: 17.6798
# against: reddit_flant5 | test_loss: 5.0749 | test_acc: 51.9500 | test_f1: 0.0885 | test_recall: 0.0467 | test_precision: 0.8589 | test_brier: 0.4719 | time: 17.8952
# against: reddit_dolly | test_loss: 2.2162 | test_acc: 56.3000 | test_f1: 0.2342 | test_recall: 0.1337 | test_precision: 0.9458 | test_brier: 0.3946 | time: 20.7478
# against: reddit_chatGPT | test_loss: 1.5284 | test_acc: 62.7167 | test_f1: 0.4127 | test_recall: 0.2620 | test_precision: 0.9716 | test_brier: 0.3265 | time: 19.7225
# Finished testing against M4 data for LSTM gpt-4-turbo-preview
# Testing against M4 data for LSTM gpt-3.5-turbo-0125...
# against: arxiv_chatGPT | test_loss: 0.8862 | test_acc: 67.1833 | test_f1: 0.6947 | test_recall: 0.7467 | test_precision: 0.6495 | test_brier: 0.2572 | time: 7.7983
# against: arxiv_bloomz | test_loss: 1.8290 | test_acc: 44.3500 | test_f1: 0.3426 | test_recall: 0.2900 | test_precision: 0.4185 | test_brier: 0.4606 | time: 8.9422
# against: arxiv_flant5 | test_loss: 1.0843 | test_acc: 67.2000 | test_f1: 0.6949 | test_recall: 0.7470 | test_precision: 0.6496 | test_brier: 0.2691 | time: 7.2155
# against: arxiv_davinci | test_loss: 1.2212 | test_acc: 58.9333 | test_f1: 0.5862 | test_recall: 0.5817 | test_precision: 0.5907 | test_brier: 0.3292 | time: 7.7494
# against: arxiv_cohere | test_loss: 1.1237 | test_acc: 61.8833 | test_f1: 0.6270 | test_recall: 0.6407 | test_precision: 0.6139 | test_brier: 0.3045 | time: 8.7751
# against: wikihow_cohere | test_loss: 4.2006 | test_acc: 38.4000 | test_f1: 0.3574 | test_recall: 0.3427 | test_precision: 0.3735 | test_brier: 0.5454 | time: 52.5850
# against: wikihow_chatGPT | test_loss: 5.1145 | test_acc: 25.2500 | test_f1: 0.0963 | test_recall: 0.0797 | test_precision: 0.1218 | test_brier: 0.6893 | time: 57.8547
# against: wikihow_dolly2 | test_loss: 4.5512 | test_acc: 33.9500 | test_f1: 0.2775 | test_recall: 0.2537 | test_precision: 0.3062 | test_brier: 0.5971 | time: 51.5110
# against: wikihow_bloomz | test_loss: 5.3693 | test_acc: 24.6833 | test_f1: 0.0832 | test_recall: 0.0683 | test_precision: 0.1063 | test_brier: 0.6996 | time: 47.7010
# against: wikihow_davinci | test_loss: 4.3740 | test_acc: 33.8000 | test_f1: 0.2747 | test_recall: 0.2507 | test_precision: 0.3037 | test_brier: 0.5875 | time: 56.3310
# against: wikipedia_cohere | test_loss: 8.0765 | test_acc: 31.9077 | test_f1: 0.3831 | test_recall: 0.4824 | test_precision: 0.3176 | test_brier: 0.6149 | time: 63.4695
# against: wikipedia_chatgpt | test_loss: 7.3409 | test_acc: 35.2588 | test_f1: 0.4414 | test_recall: 0.5115 | test_precision: 0.3881 | test_brier: 0.5735 | time: 62.8810
# against: wikipedia_davinci | test_loss: 7.3726 | test_acc: 28.8407 | test_f1: 0.3435 | test_recall: 0.3720 | test_precision: 0.3190 | test_brier: 0.6240 | time: 62.7673
# against: wikipedia_bloomz | test_loss: 7.4139 | test_acc: 35.4796 | test_f1: 0.4391 | test_recall: 0.5047 | test_precision: 0.3886 | test_brier: 0.5908 | time: 60.6752
# against: wikipedia_dolly | test_loss: 8.3143 | test_acc: 25.0483 | test_f1: 0.2916 | test_recall: 0.3253 | test_precision: 0.2643 | test_brier: 0.6843 | time: 67.0513
# against: reddit_bloomz | test_loss: 3.6348 | test_acc: 36.8667 | test_f1: 0.0642 | test_recall: 0.0433 | test_precision: 0.1240 | test_brier: 0.5900 | time: 18.2545
# against: reddit_davinci | test_loss: 1.8275 | test_acc: 53.7500 | test_f1: 0.4517 | test_recall: 0.3810 | test_precision: 0.5546 | test_brier: 0.3907 | time: 19.7829
# against: reddit_cohere | test_loss: 1.1900 | test_acc: 73.4667 | test_f1: 0.7450 | test_recall: 0.7753 | test_precision: 0.7170 | test_brier: 0.2807 | time: 17.6174
# against: reddit_flant5 | test_loss: 1.7231 | test_acc: 62.3000 | test_f1: 0.5942 | test_recall: 0.5520 | test_precision: 0.6434 | test_brier: 0.3364 | time: 17.3820
# against: reddit_dolly | test_loss: 1.8425 | test_acc: 52.7167 | test_f1: 0.4325 | test_recall: 0.3603 | test_precision: 0.5408 | test_brier: 0.4009 | time: 20.7913
# against: reddit_chatGPT | test_loss: 1.6221 | test_acc: 59.0667 | test_f1: 0.5435 | test_recall: 0.4873 | test_precision: 0.6143 | test_brier: 0.3490 | time: 19.7756
# Finished testing against M4 data for LSTM gpt-3.5-turbo-0125
# Testing against M4 data for LSTM mistralai-mixtral-8x7b-instruct-v0.1...
# against: arxiv_chatGPT | test_loss: 0.7382 | test_acc: 76.8833 | test_f1: 0.7854 | test_recall: 0.8460 | test_precision: 0.7329 | test_brier: 0.1831 | time: 7.7239
# against: arxiv_bloomz | test_loss: 1.9551 | test_acc: 44.4333 | test_f1: 0.2617 | test_recall: 0.1970 | test_precision: 0.3898 | test_brier: 0.4706 | time: 9.4224
# against: arxiv_flant5 | test_loss: 2.4461 | test_acc: 53.0667 | test_f1: 0.4406 | test_recall: 0.3697 | test_precision: 0.5452 | test_brier: 0.4148 | time: 7.3141
# against: arxiv_davinci | test_loss: 1.3721 | test_acc: 58.2667 | test_f1: 0.5316 | test_recall: 0.4737 | test_precision: 0.6057 | test_brier: 0.3415 | time: 7.7092
# against: arxiv_cohere | test_loss: 1.7133 | test_acc: 52.0333 | test_f1: 0.4212 | test_recall: 0.3490 | test_precision: 0.5309 | test_brier: 0.4068 | time: 8.8365
# against: wikihow_cohere | test_loss: 3.5751 | test_acc: 52.4667 | test_f1: 0.1159 | test_recall: 0.0623 | test_precision: 0.8274 | test_brier: 0.4545 | time: 52.5467
# against: wikihow_chatGPT | test_loss: 2.3954 | test_acc: 52.0000 | test_f1: 0.0994 | test_recall: 0.0530 | test_precision: 0.8030 | test_brier: 0.4422 | time: 57.6660
# against: wikihow_dolly2 | test_loss: 2.8107 | test_acc: 55.0833 | test_f1: 0.2034 | test_recall: 0.1147 | test_precision: 0.8982 | test_brier: 0.4119 | time: 51.3992
# against: wikihow_bloomz | test_loss: 2.7326 | test_acc: 52.2167 | test_f1: 0.1071 | test_recall: 0.0573 | test_precision: 0.8152 | test_brier: 0.4511 | time: 47.9380
# against: wikihow_davinci | test_loss: 3.0268 | test_acc: 51.8500 | test_f1: 0.0941 | test_recall: 0.0500 | test_precision: 0.7937 | test_brier: 0.4490 | time: 55.7987
# against: wikipedia_cohere | test_loss: 1.6290 | test_acc: 66.1414 | test_f1: 0.4242 | test_recall: 0.2847 | test_precision: 0.8323 | test_brier: 0.2995 | time: 63.5224
# against: wikipedia_chatgpt | test_loss: 0.6514 | test_acc: 80.1836 | test_f1: 0.7654 | test_recall: 0.6464 | test_precision: 0.9380 | test_brier: 0.1583 | time: 63.2038
# against: wikipedia_davinci | test_loss: 0.7001 | test_acc: 76.5304 | test_f1: 0.7113 | test_recall: 0.5777 | test_precision: 0.9253 | test_brier: 0.1854 | time: 63.3742
# against: wikipedia_bloomz | test_loss: 5.6874 | test_acc: 53.0942 | test_f1: 0.1892 | test_recall: 0.1093 | test_precision: 0.7009 | test_brier: 0.4416 | time: 61.3534
# against: wikipedia_dolly | test_loss: 1.9328 | test_acc: 61.5587 | test_f1: 0.3652 | test_recall: 0.2332 | test_precision: 0.8422 | test_brier: 0.3421 | time: 66.9988
# against: reddit_bloomz | test_loss: 1.8128 | test_acc: 52.4833 | test_f1: 0.1165 | test_recall: 0.0627 | test_precision: 0.8282 | test_brier: 0.4237 | time: 18.2315
# against: reddit_davinci | test_loss: 0.8866 | test_acc: 70.2667 | test_f1: 0.5845 | test_recall: 0.4183 | test_precision: 0.9699 | test_brier: 0.2458 | time: 19.8338
# against: reddit_cohere | test_loss: 37.0807 | test_acc: 78.0167 | test_f1: 0.7228 | test_recall: 0.5733 | test_precision: 0.9778 | test_brier: 0.2632 | time: 17.6284
# against: reddit_flant5 | test_loss: 2.9209 | test_acc: 61.1500 | test_f1: 0.3779 | test_recall: 0.2360 | test_precision: 0.9478 | test_brier: 0.3645 | time: 17.3867
# against: reddit_dolly | test_loss: 1.5713 | test_acc: 62.5833 | test_f1: 0.4143 | test_recall: 0.2647 | test_precision: 0.9532 | test_brier: 0.3281 | time: 20.8095
# against: reddit_chatGPT | test_loss: 1.0368 | test_acc: 71.2833 | test_f1: 0.6044 | test_recall: 0.4387 | test_precision: 0.9712 | test_brier: 0.2517 | time: 19.7358
# Finished testing against M4 data for LSTM mistralai-mixtral-8x7b-instruct-v0.1
# Testing against M4 data for LSTM /all_vs_all/all_vs_all_epoch_16...
# against: arxiv_chatGPT | test_loss: 1.6401 | test_acc: 68.5667 | test_f1: 0.7256 | test_recall: 0.8310 | test_precision: 0.6439 | test_brier: 0.2710 | time: 7.7316
# against: arxiv_bloomz | test_loss: 2.6933 | test_acc: 46.6667 | test_f1: 0.4245 | test_recall: 0.3933 | test_precision: 0.4609 | test_brier: 0.4728 | time: 9.0330
# against: arxiv_flant5 | test_loss: 1.5495 | test_acc: 72.5167 | test_f1: 0.7680 | test_recall: 0.9100 | test_precision: 0.6644 | test_brier: 0.2428 | time: 7.2903
# against: arxiv_davinci | test_loss: 2.2324 | test_acc: 56.7667 | test_f1: 0.5792 | test_recall: 0.5950 | test_precision: 0.5642 | test_brier: 0.3800 | time: 7.7120
# against: arxiv_cohere | test_loss: 2.4112 | test_acc: 55.6333 | test_f1: 0.5633 | test_recall: 0.5723 | test_precision: 0.5546 | test_brier: 0.3960 | time: 8.8331
# against: wikihow_cohere | test_loss: 1.8363 | test_acc: 65.2667 | test_f1: 0.6710 | test_recall: 0.7083 | test_precision: 0.6374 | test_brier: 0.3035 | time: 53.0699
# against: wikihow_chatGPT | test_loss: 1.9897 | test_acc: 58.9500 | test_f1: 0.5864 | test_recall: 0.5820 | test_precision: 0.5909 | test_brier: 0.3498 | time: 57.7618
# against: wikihow_dolly2 | test_loss: 2.4341 | test_acc: 54.0500 | test_f1: 0.5130 | test_recall: 0.4840 | test_precision: 0.5457 | test_brier: 0.4075 | time: 51.4409
# against: wikihow_bloomz | test_loss: 3.1628 | test_acc: 42.6333 | test_f1: 0.3083 | test_recall: 0.2557 | test_precision: 0.3882 | test_brier: 0.5193 | time: 47.7517
# against: wikihow_davinci | test_loss: 2.2683 | test_acc: 53.2500 | test_f1: 0.5003 | test_recall: 0.4680 | test_precision: 0.5373 | test_brier: 0.4037 | time: 55.8889
# against: wikipedia_cohere | test_loss: 4.5356 | test_acc: 50.8910 | test_f1: 0.5980 | test_recall: 0.8335 | test_precision: 0.4662 | test_brier: 0.4492 | time: 63.5477
# against: wikipedia_chatgpt | test_loss: 3.9837 | test_acc: 57.7629 | test_f1: 0.6826 | test_recall: 0.9082 | test_precision: 0.5467 | test_brier: 0.3846 | time: 62.7622
# against: wikipedia_davinci | test_loss: 4.0976 | test_acc: 53.1943 | test_f1: 0.6329 | test_recall: 0.8063 | test_precision: 0.5209 | test_brier: 0.4233 | time: 62.6649
# against: wikipedia_bloomz | test_loss: 4.6844 | test_acc: 42.9858 | test_f1: 0.5139 | test_recall: 0.6023 | test_precision: 0.4482 | test_brier: 0.5183 | time: 60.5464
# against: wikipedia_dolly | test_loss: 4.7041 | test_acc: 44.4620 | test_f1: 0.5342 | test_recall: 0.6714 | test_precision: 0.4435 | test_brier: 0.5039 | time: 66.8499
# against: reddit_bloomz | test_loss: 3.4538 | test_acc: 44.7667 | test_f1: 0.1489 | test_recall: 0.0967 | test_precision: 0.3244 | test_brier: 0.5149 | time: 18.2662
# against: reddit_davinci | test_loss: 1.8314 | test_acc: 61.0333 | test_f1: 0.5199 | test_recall: 0.4220 | test_precision: 0.6770 | test_brier: 0.3388 | time: 19.7555
# against: reddit_cohere | test_loss: 0.8264 | test_acc: 83.7333 | test_f1: 0.8434 | test_recall: 0.8760 | test_precision: 0.8131 | test_brier: 0.1910 | time: 18.0286
# against: reddit_flant5 | test_loss: 0.7487 | test_acc: 83.3667 | test_f1: 0.8393 | test_recall: 0.8687 | test_precision: 0.8118 | test_brier: 0.1421 | time: 17.3619
# against: reddit_dolly | test_loss: 1.4622 | test_acc: 66.4167 | test_f1: 0.6120 | test_recall: 0.5297 | test_precision: 0.7246 | test_brier: 0.2890 | time: 20.8016
# against: reddit_chatGPT | test_loss: 1.7255 | test_acc: 66.2000 | test_f1: 0.6085 | test_recall: 0.5253 | test_precision: 0.7229 | test_brier: 0.2994 | time: 19.8402
# Finished testing against M4 data for LSTM /all_vs_all/all_vs_all_epoch_16

# %%
# Create a JSON Encoder class
class json_serialize(json.JSONEncoder):
    def default(self, obj):
        if isinstance(obj, np.integer):
            return int(obj)
        if isinstance(obj, np.floating):
            return float(obj)
        if isinstance(obj, np.ndarray):
            return obj.tolist()
        return json.JSONEncoder.default(self, obj)

with open('./vs_m4.json', 'w', encoding='utf-8') as f:
    json.dump(final_results, f, ensure_ascii=False, indent=4, cls=json_serialize)
